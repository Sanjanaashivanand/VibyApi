# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Importing Data

# %%
Dataset = pd.read_csv('./Data/Training/TrainingDataset.csv')
Dataset = Dataset.drop(['track_name','artist_name','album_name','album_cover','release_date',
                        'preview_link','spotify_link','name', 'length','timeSignature'], axis=1)
Dataset.dropna(inplace=True)
Dataset = Dataset.sample(frac=1)
Dataset = Dataset.drop_duplicates(subset=["id"], keep='first')
Dataset
# Out:
#                           id playlist_mood  acousticness  danceability  \
# 1836  3QaCI3akUy8kDD1tMUGspR       Content      0.391000         0.744
# 2510  5IDYiDJLlEL4Mscj33ao83        Sleepy      0.939000         0.159
# 2039  6Ln89sczgIcAJXGAIdS94R          Calm      0.897000         0.389
# 1635  26kPTDeIh5pTcyMuD6IonN       Content      0.874000         0.472
# 3607  6fScgF2Y63ScU73nYju0ny           Sad      0.588000         0.481
# ...                      ...           ...           ...           ...
# 3441  5a6pdCHlWS2ekOOQ70QnAr           Sad      0.868000         0.708
# 2457  5tfnG31hpSaIGTFLVUdlEx        Sleepy      0.994000         0.275
# 4172  67jewFqrAXWR8rpfJSX8sr         Angry      0.000807         0.487
# 1509  6zvvWWxsMIhEYLMTRcWHfc         Happy      0.135000         0.745
# 301   2Cd9iWfcOpGDHLz6tVA3G4       Excited      0.006270         0.766
#
#       energy  instrumentalness  liveness  loudness  speechiness    tempo  \
# 1836  0.4390          0.874000    0.3610    -7.168       0.0433  130.003
# 2510  0.0149          0.928000    0.1300   -33.825       0.0482   68.808
# 2039  0.1480          0.000000    0.1140   -11.011       0.0300  142.611
# 1635  0.4930          0.000265    0.1880   -10.607       0.4170  139.631
# 3607  0.4960          0.000000    0.1320    -7.421       0.0262   89.839
# ...      ...               ...       ...       ...          ...      ...
# 3441  0.1860          0.000000    0.0779    -8.953       0.0422   72.541
# 2457  0.0265          0.935000    0.0999   -31.405       0.0393   68.926
# 4172  0.9850          0.000000    0.1820    -3.372       0.0794   92.000
# 1509  0.7450          0.001750    0.1120    -7.481       0.0706  103.991
# 301   0.8730          0.000000    0.0764    -6.381       0.1430  126.988
#
#       valence
# 1836   0.4340
# 2510   0.0273
# 2039   0.4000
# 1635   0.5680
# 3607   0.4530
# ...       ...
# 3441   0.3210
# 2457   0.1740
# 4172   0.2520
# 1509   0.5130
# 301    0.7430
#
# [3978 rows x 11 columns]

# %%
#Happy
Dataset = Dataset.replace(to_replace="Delighted",value="Happy")
Dataset = Dataset.replace(to_replace="Excited",value="Happy")

# %%
#Calm
Dataset = Dataset.replace(to_replace="Content",value="Calm")
Dataset = Dataset.replace(to_replace="Sleepy",value="Calm")

# %%
#Sad
Dataset = Dataset.replace(to_replace="Depressed",value="Sad")

# %%
Dataset
# Out:
#                           id playlist_mood  acousticness  danceability  \
# 1836  3QaCI3akUy8kDD1tMUGspR          Calm      0.391000         0.744
# 2510  5IDYiDJLlEL4Mscj33ao83          Calm      0.939000         0.159
# 2039  6Ln89sczgIcAJXGAIdS94R          Calm      0.897000         0.389
# 1635  26kPTDeIh5pTcyMuD6IonN          Calm      0.874000         0.472
# 3607  6fScgF2Y63ScU73nYju0ny           Sad      0.588000         0.481
# ...                      ...           ...           ...           ...
# 3441  5a6pdCHlWS2ekOOQ70QnAr           Sad      0.868000         0.708
# 2457  5tfnG31hpSaIGTFLVUdlEx          Calm      0.994000         0.275
# 4172  67jewFqrAXWR8rpfJSX8sr         Angry      0.000807         0.487
# 1509  6zvvWWxsMIhEYLMTRcWHfc         Happy      0.135000         0.745
# 301   2Cd9iWfcOpGDHLz6tVA3G4         Happy      0.006270         0.766
#
#       energy  instrumentalness  liveness  loudness  speechiness    tempo  \
# 1836  0.4390          0.874000    0.3610    -7.168       0.0433  130.003
# 2510  0.0149          0.928000    0.1300   -33.825       0.0482   68.808
# 2039  0.1480          0.000000    0.1140   -11.011       0.0300  142.611
# 1635  0.4930          0.000265    0.1880   -10.607       0.4170  139.631
# 3607  0.4960          0.000000    0.1320    -7.421       0.0262   89.839
# ...      ...               ...       ...       ...          ...      ...
# 3441  0.1860          0.000000    0.0779    -8.953       0.0422   72.541
# 2457  0.0265          0.935000    0.0999   -31.405       0.0393   68.926
# 4172  0.9850          0.000000    0.1820    -3.372       0.0794   92.000
# 1509  0.7450          0.001750    0.1120    -7.481       0.0706  103.991
# 301   0.8730          0.000000    0.0764    -6.381       0.1430  126.988
#
#       valence
# 1836   0.4340
# 2510   0.0273
# 2039   0.4000
# 1635   0.5680
# 3607   0.4530
# ...       ...
# 3441   0.3210
# 2457   0.1740
# 4172   0.2520
# 1509   0.5130
# 301    0.7430
#
# [3978 rows x 11 columns]

# %%
X = Dataset.iloc[:, 2:]
y = Dataset.iloc[:, 1]

# %% [markdown]
# # Data Preprocessing

# %%
#Encoding
yLabels = y.copy()

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
y = le.fit_transform(y)

# %%
DecodingMap = pd.DataFrame({'encoding': y,'mood': yLabels}).drop_duplicates().set_index('mood')

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
X_train
# Out:
#       acousticness  danceability  energy  instrumentalness  liveness  \
# 2736      0.827000         0.171  0.0755          0.632000    0.1070
# 542       0.001330         0.291  0.7900          0.000006    0.0811
# 170       0.006120         0.809  0.8730          0.000009    0.0732
# 3632      0.450000         0.308  0.5850          0.000000    0.3190
# 192       0.164000         0.868  0.6350          0.000000    0.0898
# ...            ...           ...     ...               ...       ...
# 4223      0.000209         0.429  0.9660          0.124000    0.3710
# 3454      0.624000         0.685  0.5700          0.000098    0.1250
# 776       0.629000         0.745  0.4320          0.000000    0.3510
# 1991      0.990000         0.436  0.0786          0.893000    0.1100
# 1648      0.117000         0.567  0.5930          0.000001    0.2480
#
#       loudness  speechiness    tempo  valence
# 2736   -29.598       0.0492   74.955    0.267
# 542     -5.683       0.0363  155.667    0.513
# 170     -2.455       0.0556  100.013    0.340
# 3632    -5.180       0.0428  171.843    0.345
# 192     -6.352       0.2270   90.019    0.621
# ...        ...          ...      ...      ...
# 4223    -4.605       0.0733  179.956    0.525
# 3454    -5.485       0.0303  110.512    0.438
# 776     -8.092       0.0406  104.018    0.693
# 1991   -24.044       0.0358   97.200    0.287
# 1648    -7.404       0.2880   88.545    0.358
#
# [3182 rows x 9 columns]

# %%
#Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0, max_iter=2000)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=2000, random_state=0)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.7047738693467337

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.7010050251256281

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'linear', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.7123115577889447

# %% [markdown]
# # Kernel SVM

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'rbf', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# SVC(random_state=0)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.7135678391959799

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.6771356783919598

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.6733668341708543

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
RFclassifier = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)
RFclassifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
y_pred = RFclassifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.7273869346733668

# %% [markdown]
# # Deploying the model

# %%
Test_Data = pd.read_csv('../Dataset.csv')
Test_Data = Test_Data.drop_duplicates(subset=["id"], keep='first')
X = Test_Data[['acousticness','danceability','energy','instrumentalness','liveness','loudness','speechiness','tempo','valence']]

# %%
X = sc.transform(X)
X
# Out:
# array([[-0.76767384,  0.51542094,  0.22304872, ..., -0.73756528,
#         -0.52489576, -0.22934351],
#        [ 0.53892656,  0.03900775, -0.46797235, ..., -0.38072013,
#          0.06832619, -1.05097546],
#        [ 0.54152417,  0.59320269, -0.26616974, ..., -0.68010716,
#         -0.74514542,  0.2366567 ],
#        ...,
#        [-1.11627379, -0.30614875,  1.37271209, ...,  0.82741237,
#         -0.70005469,  0.25300759],
#        [ 1.22209933,  0.02928503, -1.14064773, ..., -0.33233435,
#          0.43958459, -0.18437858],
#        [-0.61181693,  1.62381083,  0.96299163, ...,  1.20542629,
#          0.19032356,  1.9003592 ]])

# %%
RFclassifier.predict(X)
# Out:
# array([2, 1, 3, ..., 0, 2, 2])

# %%
Test_Data['playlist_mood'] = RFclassifier.predict(X)
Test_Data
# Out:
#                            id        genre  \
# 0      4gs07VlJST4bdxGbBsXVue     acoustic
# 1      0SuG9kyzGRpDqrCWtgD6Lq     acoustic
# 2      0vWjNkwgkTnyzfeLdTKWJ7     acoustic
# 3      1NdgDGYG4J827IvfeDgF4o     acoustic
# 4      54KFQB6N4pn926IUUYZGzK     acoustic
# ...                       ...          ...
# 11152  5EcaGTbrp1SkFrnrpAoGbm  world-music
# 11153  131sSSMin9GSNXBMCPsJpv  world-music
# 11154  3CCGsOj2efotChiScMmCWg  world-music
# 11155  5i2sgqnzaxYpvXmGAB592h  world-music
# 11156  5RKy4qx5G3wXpwLXjTO02C  world-music
#
#                                     track_name  \
# 0                           Heartbreak Warfare
# 1                                 Give Me Love
# 2                                         Roar
# 3                           Dear Mr. President
# 4                              To Build A Home
# ...                                        ...
# 11152                   De Nua feat. Ana Moura
# 11153                                   Vision
# 11154                           A Minha Menina
# 11155  Corcovado - Quiet Nights Of Quiet Stars
# 11156              Mahalageasca - Bucovina Dub
#
#                                              artist_name  \
# 0                                             John Mayer
# 1                                             Ed Sheeran
# 2                                     Alex Goot,Sam Tsui
# 3                                                   P!nk
# 4                 The Cinematic Orchestra,Patrick Watson
# ...                                                  ...
# 11152  Sara Tavares feat. Ana Moura,Sara Tavares,Ana ...
# 11153                                        Mo'kalamity
# 11154                                        Os Mutantes
# 11155  Stan Getz,João Gilberto,Astrud Gilberto,Antôni...
# 11156                                   Mahala Rai Banda
#
#                                            album_name  \
# 0                                      Battle Studies
# 1                                                   +
# 2                                                Roar
# 3                                    The People Speak
# 4                                            Ma Fleur
# ...                                               ...
# 11152                                         Balancé
# 11153                               Warriors of light
# 11154                                   "Os Mutantes"
# 11155  Getz/Gilberto (Classics International Version)
# 11156              Gypsy Beats and Balkan Bangers E.P
#
#                                              album_cover release_date  \
# 0      https://i.scdn.co/image/ab67616d0000b2731e3dbe...   2009-11-13
# 1      https://i.scdn.co/image/ab67616d0000b273ed139c...   2011-09-09
# 2      https://i.scdn.co/image/ab67616d0000b273742fa6...   2013-09-17
# 3      https://i.scdn.co/image/ab67616d0000b27380f5f9...   2009-01-01
# 4      https://i.scdn.co/image/ab67616d0000b273e91011...   2007-05-07
# ...                                                  ...          ...
# 11152  https://i.scdn.co/image/ab67616d0000b273cfcdea...   2005-10-18
# 11153  https://i.scdn.co/image/ab67616d0000b273cc5fe2...   2007-02-27
# 11154  https://i.scdn.co/image/ab67616d0000b27369a068...   1968-01-01
# 11155  https://i.scdn.co/image/ab67616d0000b2738d9a27...      1964-04
# 11156  https://i.scdn.co/image/ab67616d0000b273dc1625...   2006-06-11
#
#                                             preview_link  \
# 0      https://p.scdn.co/mp3-preview/cce088114300e08d...
# 1      https://p.scdn.co/mp3-preview/1750e0969080492c...
# 2      https://p.scdn.co/mp3-preview/bf9138f2eb6dbed3...
# 3                                                    NaN
# 4      https://p.scdn.co/mp3-preview/9f30342a6568f55c...
# ...                                                  ...
# 11152                                                NaN
# 11153  https://p.scdn.co/mp3-preview/e23062ec725a33c0...
# 11154                                                NaN
# 11155                                                NaN
# 11156                                                NaN
#
#                                             spotify_link  acousticness  \
# 0      https://open.spotify.com/track/4gs07VlJST4bdxG...        0.1910
# 1      https://open.spotify.com/track/0SuG9kyzGRpDqrC...        0.6940
# 2      https://open.spotify.com/track/0vWjNkwgkTnyzfe...        0.6950
# 3      https://open.spotify.com/track/1NdgDGYG4J827Iv...        0.8490
# 4      https://open.spotify.com/track/54KFQB6N4pn926I...        0.8850
# ...                                                  ...           ...
# 11152  https://open.spotify.com/track/5EcaGTbrp1SkFrn...        0.8900
# 11153  https://open.spotify.com/track/131sSSMin9GSNXB...        0.0266
# 11154  https://open.spotify.com/track/3CCGsOj2efotChi...        0.0568
# 11155  https://open.spotify.com/track/5i2sgqnzaxYpvXm...        0.9570
# 11156  https://open.spotify.com/track/5RKy4qx5G3wXpwL...        0.2510
#
#        danceability  energy  instrumentalness  liveness  loudness  \
# 0             0.624   0.554          0.001310    0.2990    -8.113
# 1             0.526   0.328          0.000000    0.1120    -9.864
# 2             0.640   0.394          0.000000    0.0741    -7.258
# 3             0.476   0.299          0.000000    0.1130    -9.154
# 4             0.264   0.122          0.349000    0.0940   -15.399
# ...             ...     ...               ...       ...       ...
# 11152         0.599   0.299          0.092300    0.0788   -14.672
# 11153         0.884   0.471          0.000046    0.1400    -6.919
# 11154         0.455   0.930          0.000000    0.4640    -3.210
# 11155         0.524   0.108          0.001230    0.1390   -18.361
# 11156         0.852   0.796          0.696000    0.1020    -5.728
#
#        speechiness    tempo  valence  playlist_mood
# 0           0.0225   97.031   0.3110              2
# 1           0.0461  116.068   0.1100              1
# 2           0.0263   89.963   0.4250              3
# 3           0.0385  128.039   0.2970              3
# 4           0.0349  148.658   0.0735              1
# ...            ...      ...      ...            ...
# 11152       0.0873  113.604   0.3160              3
# 11153       0.0425  107.027   0.6460              2
# 11154       0.1260   91.410   0.4290              0
# 11155       0.0493  127.982   0.3220              2
# 11156       0.1510  119.983   0.8320              2
#
# [11157 rows x 19 columns]

# %%
d = DecodingMap.to_dict()['encoding']
d = dict([(value,key) for key, value in d.items()])
d
# Out:
# {1: 'Calm', 3: 'Sad', 2: 'Happy', 0: 'Angry'}

# %%
Test_Data['playlist_mood'] = Test_Data['playlist_mood'].map(d)
Test_Data
# Out:
#                            id        genre  \
# 0      4gs07VlJST4bdxGbBsXVue     acoustic
# 1      0SuG9kyzGRpDqrCWtgD6Lq     acoustic
# 2      0vWjNkwgkTnyzfeLdTKWJ7     acoustic
# 3      1NdgDGYG4J827IvfeDgF4o     acoustic
# 4      54KFQB6N4pn926IUUYZGzK     acoustic
# ...                       ...          ...
# 11152  5EcaGTbrp1SkFrnrpAoGbm  world-music
# 11153  131sSSMin9GSNXBMCPsJpv  world-music
# 11154  3CCGsOj2efotChiScMmCWg  world-music
# 11155  5i2sgqnzaxYpvXmGAB592h  world-music
# 11156  5RKy4qx5G3wXpwLXjTO02C  world-music
#
#                                     track_name  \
# 0                           Heartbreak Warfare
# 1                                 Give Me Love
# 2                                         Roar
# 3                           Dear Mr. President
# 4                              To Build A Home
# ...                                        ...
# 11152                   De Nua feat. Ana Moura
# 11153                                   Vision
# 11154                           A Minha Menina
# 11155  Corcovado - Quiet Nights Of Quiet Stars
# 11156              Mahalageasca - Bucovina Dub
#
#                                              artist_name  \
# 0                                             John Mayer
# 1                                             Ed Sheeran
# 2                                     Alex Goot,Sam Tsui
# 3                                                   P!nk
# 4                 The Cinematic Orchestra,Patrick Watson
# ...                                                  ...
# 11152  Sara Tavares feat. Ana Moura,Sara Tavares,Ana ...
# 11153                                        Mo'kalamity
# 11154                                        Os Mutantes
# 11155  Stan Getz,João Gilberto,Astrud Gilberto,Antôni...
# 11156                                   Mahala Rai Banda
#
#                                            album_name  \
# 0                                      Battle Studies
# 1                                                   +
# 2                                                Roar
# 3                                    The People Speak
# 4                                            Ma Fleur
# ...                                               ...
# 11152                                         Balancé
# 11153                               Warriors of light
# 11154                                   "Os Mutantes"
# 11155  Getz/Gilberto (Classics International Version)
# 11156              Gypsy Beats and Balkan Bangers E.P
#
#                                              album_cover release_date  \
# 0      https://i.scdn.co/image/ab67616d0000b2731e3dbe...   2009-11-13
# 1      https://i.scdn.co/image/ab67616d0000b273ed139c...   2011-09-09
# 2      https://i.scdn.co/image/ab67616d0000b273742fa6...   2013-09-17
# 3      https://i.scdn.co/image/ab67616d0000b27380f5f9...   2009-01-01
# 4      https://i.scdn.co/image/ab67616d0000b273e91011...   2007-05-07
# ...                                                  ...          ...
# 11152  https://i.scdn.co/image/ab67616d0000b273cfcdea...   2005-10-18
# 11153  https://i.scdn.co/image/ab67616d0000b273cc5fe2...   2007-02-27
# 11154  https://i.scdn.co/image/ab67616d0000b27369a068...   1968-01-01
# 11155  https://i.scdn.co/image/ab67616d0000b2738d9a27...      1964-04
# 11156  https://i.scdn.co/image/ab67616d0000b273dc1625...   2006-06-11
#
#                                             preview_link  \
# 0      https://p.scdn.co/mp3-preview/cce088114300e08d...
# 1      https://p.scdn.co/mp3-preview/1750e0969080492c...
# 2      https://p.scdn.co/mp3-preview/bf9138f2eb6dbed3...
# 3                                                    NaN
# 4      https://p.scdn.co/mp3-preview/9f30342a6568f55c...
# ...                                                  ...
# 11152                                                NaN
# 11153  https://p.scdn.co/mp3-preview/e23062ec725a33c0...
# 11154                                                NaN
# 11155                                                NaN
# 11156                                                NaN
#
#                                             spotify_link  acousticness  \
# 0      https://open.spotify.com/track/4gs07VlJST4bdxG...        0.1910
# 1      https://open.spotify.com/track/0SuG9kyzGRpDqrC...        0.6940
# 2      https://open.spotify.com/track/0vWjNkwgkTnyzfe...        0.6950
# 3      https://open.spotify.com/track/1NdgDGYG4J827Iv...        0.8490
# 4      https://open.spotify.com/track/54KFQB6N4pn926I...        0.8850
# ...                                                  ...           ...
# 11152  https://open.spotify.com/track/5EcaGTbrp1SkFrn...        0.8900
# 11153  https://open.spotify.com/track/131sSSMin9GSNXB...        0.0266
# 11154  https://open.spotify.com/track/3CCGsOj2efotChi...        0.0568
# 11155  https://open.spotify.com/track/5i2sgqnzaxYpvXm...        0.9570
# 11156  https://open.spotify.com/track/5RKy4qx5G3wXpwL...        0.2510
#
#        danceability  energy  instrumentalness  liveness  loudness  \
# 0             0.624   0.554          0.001310    0.2990    -8.113
# 1             0.526   0.328          0.000000    0.1120    -9.864
# 2             0.640   0.394          0.000000    0.0741    -7.258
# 3             0.476   0.299          0.000000    0.1130    -9.154
# 4             0.264   0.122          0.349000    0.0940   -15.399
# ...             ...     ...               ...       ...       ...
# 11152         0.599   0.299          0.092300    0.0788   -14.672
# 11153         0.884   0.471          0.000046    0.1400    -6.919
# 11154         0.455   0.930          0.000000    0.4640    -3.210
# 11155         0.524   0.108          0.001230    0.1390   -18.361
# 11156         0.852   0.796          0.696000    0.1020    -5.728
#
#        speechiness    tempo  valence playlist_mood
# 0           0.0225   97.031   0.3110         Happy
# 1           0.0461  116.068   0.1100          Calm
# 2           0.0263   89.963   0.4250           Sad
# 3           0.0385  128.039   0.2970           Sad
# 4           0.0349  148.658   0.0735          Calm
# ...            ...      ...      ...           ...
# 11152       0.0873  113.604   0.3160           Sad
# 11153       0.0425  107.027   0.6460         Happy
# 11154       0.1260   91.410   0.4290         Angry
# 11155       0.0493  127.982   0.3220         Happy
# 11156       0.1510  119.983   0.8320         Happy
#
# [11157 rows x 19 columns]

# %%
HappyPlaylist = Test_Data.loc[Test_Data['playlist_mood'] == "Happy"]
SadPlaylist = Test_Data.loc[Test_Data['playlist_mood'] == "Sad"]
AngryPlaylist = Test_Data.loc[Test_Data['playlist_mood'] == "Angry"]
CalmPlaylist = Test_Data.loc[Test_Data['playlist_mood'] == "Calm"]

# %%
import os
path = './Data/Models/M2Playlists'
if not os.path.exists(path):
    os.makedirs(path)

csvPath = os.path.join(path, 'Happy.csv')
HappyPlaylist.to_csv(csvPath, index=False)

csvPath = os.path.join(path, 'Calm.csv')
CalmPlaylist.to_csv(csvPath, index=False)

csvPath = os.path.join(path, 'Sad.csv')
SadPlaylist.to_csv(csvPath, index=False)

csvPath = os.path.join(path, 'Angry.csv')
AngryPlaylist.to_csv(csvPath, index=False)

# %%
mood = "Angry"
DF = pd.read_csv('./Data/Models/M1Playlists/' + mood +'.csv')

# %%
DF
# Out:
#                           id        genre               track_name  \
# 0     5oCMnpuRd3rUL9clNWbjr0     acoustic           My Hero - Live
# 1     13ETkZ90sElK5xJuB4cUEt     acoustic            Bonfire Heart
# 2     6YxRTkyPebNVzd2VAEQFF3     afrobeat                      Eko
# 3     19pQaJUSEtn31fpO6RozaH     alt-rock  A Million Little Pieces
# 4     0EYOdF5FCkgOJJla8DI2Md     alt-rock                 B.Y.O.B.
# ...                      ...          ...                      ...
# 2212  7tEETVJYcqhZ3gZCPUyiqU  world-music                     Aman
# 2213  2KS2NkCbrfijMYvuIJawDU  world-music                 Mandinga
# 2214  2SGfKTYnLLX1UCEA84O6IZ  world-music                   Zombie
# 2215  6uNipqGXOCj8Q8ufRemutC  world-music            Dreambuilding
# 2216  3CCGsOj2efotChiScMmCWg  world-music           A Minha Menina
#
#                                             artist_name  \
# 0                                          Foo Fighters
# 1                                           James Blunt
# 2                                             Fela Kuti
# 3                                               Placebo
# 4                                      System Of A Down
# ...                                                 ...
# 2212                                            Bombino
# 2213  Octavio Calderon,Manuel Guajiro Mirabal,Ibrahi...
# 2214                                          Fela Kuti
# 2215                                               Goat
# 2216                                        Os Mutantes
#
#                                     album_name  \
# 0                               Skin And Bones
# 1                Moon Landing (Deluxe Edition)
# 2                 The '69 Los Angeles Sessions
# 3                               Loud Like Love
# 4                                    Mezmerize
# ...                                        ...
# 2212                                     Nomad
# 2213  Buena Vista Social Club At Carnegie Hall
# 2214          The Music of Grand Theft Auto IV
# 2215                             Dreambuilding
# 2216                             "Os Mutantes"
#
#                                             album_cover release_date  \
# 0     https://i.scdn.co/image/ab67616d0000b2739b0fe5...   2006-11-07
# 1     https://i.scdn.co/image/ab67616d0000b273bd82db...   2013-10-18
# 2     https://i.scdn.co/image/ab67616d0000b273d4cb32...         1994
# 3     https://i.scdn.co/image/ab67616d0000b27399c037...   2013-01-01
# 4     https://i.scdn.co/image/ab67616d0000b273c65f8d...   2005-05-17
# ...                                                 ...          ...
# 2212  https://i.scdn.co/image/ab67616d0000b273dfff3c...   2013-01-28
# 2213  https://i.scdn.co/image/ab67616d0000b2734a16c7...   2008-10-13
# 2214  https://i.scdn.co/image/ab67616d0000b273e2f78a...   2008-01-01
# 2215  https://i.scdn.co/image/ab67616d0000b273b19556...   2013-01-01
# 2216  https://i.scdn.co/image/ab67616d0000b27369a068...   1968-01-01
#
#                                            preview_link  \
# 0                                                   NaN
# 1                                                   NaN
# 2     https://p.scdn.co/mp3-preview/562f191295564737...
# 3                                                   NaN
# 4     https://p.scdn.co/mp3-preview/6d17f13307a49b61...
# ...                                                 ...
# 2212  https://p.scdn.co/mp3-preview/0584d0b07d15649f...
# 2213                                                NaN
# 2214  https://p.scdn.co/mp3-preview/e656f7c69267c79a...
# 2215                                                NaN
# 2216                                                NaN
#
#                                            spotify_link  acousticness  \
# 0     https://open.spotify.com/track/5oCMnpuRd3rUL9c...      0.013700
# 1     https://open.spotify.com/track/13ETkZ90sElK5xJ...      0.181000
# 2     https://open.spotify.com/track/6YxRTkyPebNVzd2...      0.005940
# 3     https://open.spotify.com/track/19pQaJUSEtn31fp...      0.006200
# 4     https://open.spotify.com/track/0EYOdF5FCkgOJJl...      0.006620
# ...                                                 ...           ...
# 2212  https://open.spotify.com/track/7tEETVJYcqhZ3gZ...      0.000739
# 2213  https://open.spotify.com/track/2KS2NkCbrfijMYv...      0.721000
# 2214  https://open.spotify.com/track/2SGfKTYnLLX1UCE...      0.412000
# 2215  https://open.spotify.com/track/6uNipqGXOCj8Q8u...      0.004230
# 2216  https://open.spotify.com/track/3CCGsOj2efotChi...      0.056800
#
#       danceability  energy  instrumentalness  liveness  loudness  speechiness  \
# 0            0.312   0.812          0.000405    0.9600    -6.162       0.0566
# 1            0.575   0.821          0.000000    0.1240    -5.700       0.0527
# 2            0.351   0.867          0.394000    0.0668    -5.791       0.2230
# 3            0.531   0.858          0.043400    0.2040    -6.589       0.0326
# 4            0.538   0.981          0.000000    0.2190    -2.688       0.1400
# ...            ...     ...               ...       ...       ...          ...
# 2212         0.239   0.720          0.006000    0.1130    -7.827       0.1430
# 2213         0.552   0.880          0.888000    0.9180    -7.898       0.0896
# 2214         0.644   0.965          0.013000    0.4080    -3.799       0.2140
# 2215         0.551   0.923          0.090100    0.0924    -3.862       0.0830
# 2216         0.455   0.930          0.000000    0.4640    -3.210       0.1260
#
#         tempo  valence playlist_mood
# 0     134.414    0.184         Angry
# 1     118.021    0.449         Angry
# 2     192.853    0.894         Angry
# 3     174.007    0.606         Angry
# 4     101.414    0.711         Angry
# ...       ...      ...           ...
# 2212  176.862    0.304         Angry
# 2213   80.784    0.572         Angry
# 2214  130.374    0.588         Angry
# 2215  117.003    0.337         Angry
# 2216   91.410    0.429         Angry
#
# [2217 rows x 19 columns]
